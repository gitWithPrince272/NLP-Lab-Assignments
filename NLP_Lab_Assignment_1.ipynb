# %% [markdown]
# <a href="https://colab.research.google.com/github/gitWithPrince272/NLP-Lab-Assignments/blob/main/NLP_Lab_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("NLP Lab Assignment 1")
print("Libraries imported successfully!")
# Out:
# NLP Lab Assignment 1
# Libraries imported successfully!

# %%
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("NLTK version:", nltk.__version__)
# Out:
# Pandas version: 2.2.3
# NumPy version: 2.0.2
# NLTK version: 3.9.1
